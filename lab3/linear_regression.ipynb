# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing()
y = pd.DataFrame(data.target, columns=["target_names"])
housing_data = fetch_california_housing(as_frame=True)
df = housing_data.frame
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
y
# Out:
#        target_names
# 0             4.526
# 1             3.585
# 2             3.521
# 3             3.413
# 4             3.422
# ...             ...
# 20635         0.781
# 20636         0.771
# 20637         0.923
# 20638         0.847
# 20639         0.894
#
# [20640 rows x 1 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(df, y, test_size=0.1, random_state=42)

# %%
x_test
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20046  1.6812      25.0  4.192201   1.022284      1392.0  3.877437     36.06
# 3024   2.5313      30.0  5.039384   1.193493      1565.0  2.679795     35.14
# 15663  3.4801      52.0  3.977155   1.185877      1310.0  1.360332     37.80
# 20484  5.7376      17.0  6.163636   1.020202      1705.0  3.444444     34.28
# 9814   3.7250      34.0  5.492991   1.028037      1063.0  2.483645     36.62
# ...       ...       ...       ...        ...         ...       ...       ...
# 9477   3.5880      32.0  5.803758   0.981211      1281.0  2.674322     39.43
# 46     2.0260      50.0  3.700658   1.059211       616.0  2.026316     37.83
# 20462  5.8578      21.0  8.652174   1.062112      1114.0  3.459627     34.28
# 4751   2.2554      39.0  4.134185   1.054313      1140.0  3.642173     34.04
# 13298  3.4950      35.0  4.956522   0.952569       729.0  2.881423     34.08
#
#        Longitude  MedHouseVal
# ...

# %%
y_test
# Out:
#        target_names
# 20046       0.47700
# 3024        0.45800
# 15663       5.00001
# 20484       2.18600
# 9814        2.78000
# ...             ...
# 9477        0.96000
# 46          1.42500
# 20462       2.66300
# 4751        1.65000
# 13298       1.18000
#
# [2064 rows x 1 columns]

# %%
x_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 5564   3.8372      41.0  5.265957   1.131915      1416.0  3.012766     33.91
# 16016  8.0069      52.0  7.224033   1.030550      1276.0  2.598778     37.73
# 17131  3.6712      30.0  3.659983   1.084568      2678.0  2.334786     37.46
# 11752  3.1583      16.0  5.622378   1.034965       792.0  2.769231     38.76
# 2308   4.9292      15.0  6.333333   0.988662      1411.0  3.199546     36.83
# ...       ...       ...       ...        ...         ...       ...       ...
# 11284  6.3700      35.0  6.129032   0.926267       658.0  3.032258     33.78
# 11964  3.0500      33.0  6.868597   1.269488      1753.0  3.904232     34.02
# 5390   2.9344      36.0  3.986717   1.079696      1756.0  3.332068     34.03
# 860    5.7192      15.0  6.395349   1.067979      1777.0  3.178891     37.58
# 15795  2.5755      52.0  3.402576   1.058776      2619.0  2.108696     37.77
#
#        Longitude  MedHouseVal
# ...

# %%
y_train
# Out:
#        target_names
# 5564          1.564
# 16016         4.268
# 17131         3.086
# 11752         2.392
# 2308          1.094
# ...             ...
# 11284         2.292
# 11964         0.978
# 5390          2.221
# 860           2.835
# 15795         3.250
#
# [18576 rows x 1 columns]

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[ 3.20531255e-17, -6.66133815e-16, -8.46892808e-16,
#          6.74641546e-15,  9.57677730e-17, -2.32266765e-17,
#         -4.79767892e-16, -1.42148905e-15,  1.00000000e+00]])

# %%
model.intercept_
# Out:
# array([-2.72670775e-13])

# %%
y_pred = model.predict(x_test)

# %%
y_test
# Out:
#        target_names
# 20046       0.47700
# 3024        0.45800
# 15663       5.00001
# 20484       2.18600
# 9814        2.78000
# ...             ...
# 9477        0.96000
# 46          1.42500
# 20462       2.66300
# 4751        1.65000
# 13298       1.18000
#
# [2064 rows x 1 columns]

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 1.0933340439451201e-26

# %%
import seaborn as sns

# %%
x = df[['MedInc']]
x['target'] = y
x
# Out:
# /var/folders/8c/qcjvnzpn1dlfcj4nkf21r7sw0000gp/T/ipykernel_74834/1612095885.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['target'] = y
#        MedInc  target
# 0      8.3252   4.526
# 1      8.3014   3.585
# 2      7.2574   3.521
# 3      5.6431   3.413
# 4      3.8462   3.422
# ...       ...     ...
# 20635  1.5603   0.781
# 20636  2.5568   0.771
# 20637  1.7000   0.923
# 20638  1.8672   0.847
# 20639  2.3886   0.894
#
# [20640 rows x 2 columns]

# %%
import plotly.express as px
px.scatter(x, x='MedInc', y='target', trendline='ols', trendline_color_override='red')
